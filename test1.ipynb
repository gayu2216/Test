# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random

# Extract the data from Spark DataFrame to a NumPy array
data = np.array(range(1000))

# Create a histogram
plt.hist(data, bins=10, color="steelblue", edgecolor="black")

# Set labels and title
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram Example")

# Show the plot
plt.show()
